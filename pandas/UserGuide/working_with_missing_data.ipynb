# %%
import pandas as pd
import numpy as np

# %%
s = None
p = None

# %%
s==p
# Out:
# True

# %%
s = np.nan
p = np.nan

s==p
# Out:
# False

# %% [markdown]
# Difference expression of missing value
#
# Numeric: nan, or np.nan
#
# Object: None or whatever is given
#
# DateTIme: NaT

# %%
s = pd.Series([1,'a','aw2', None], dtype=object)
# Out:
# 0       1
# 1       a
# 2     aw2
# 3    None
# dtype: object

# %%
df = pd.DataFrame(data=np.random.randint(0,5,(4,4)),
                 index=list('abcd'),
                 columns=list('ABCD'))
df
# Out:
#    A  B  C  D
# a  1  3  4  3
# b  2  1  1  3
# c  0  3  0  1
# d  0  3  0  2

# %%
df['E'] = df['D']>=3

# %%
df['E']
# Out:
# a     True
# b     True
# c    False
# d    False
# Name: E, dtype: bool

# %%
df
# Out:
#    A  B  C  D      E
# a  1  3  4  3   True
# b  2  1  1  3   True
# c  0  3  0  1  False
# d  0  3  0  2  False

# %%
df2 = df.reindex(["a", "b", "c", "d", "e", "f", "g", "h"])
df2
# Out:
#      A    B    C    D      E
# a  1.0  3.0  4.0  3.0   True
# b  2.0  1.0  1.0  3.0   True
# c  0.0  3.0  0.0  1.0  False
# d  0.0  3.0  0.0  2.0  False
# e  NaN  NaN  NaN  NaN    NaN
# f  NaN  NaN  NaN  NaN    NaN
# g  NaN  NaN  NaN  NaN    NaN
# h  NaN  NaN  NaN  NaN    NaN

# %%
df = pd.DataFrame(
    np.random.randn(5, 3),
    index=["a", "c", "e", "f", "h"],
    columns=["one", "two", "three"],
)

df
# Out:
#         one       two     three
# a -2.724919 -0.879403 -0.119714
# c  0.577318 -0.241615  0.922915
# e -0.415512  0.253216  0.685635
# f  1.351467  1.846179  0.180370
# h  0.719194 -0.297595  0.874191

# %%
df["four"] = "bar"

df["five"] = df["one"] > 0

# %%
df2 = df.reindex(["a", "b", "c", "d", "e", "f", "g", "h"])
df2
# Out:
#         one       two     three four   five
# a -2.724919 -0.879403 -0.119714  bar  False
# b       NaN       NaN       NaN  NaN    NaN
# c  0.577318 -0.241615  0.922915  bar   True
# d       NaN       NaN       NaN  NaN    NaN
# e -0.415512  0.253216  0.685635  bar  False
# f  1.351467  1.846179  0.180370  bar   True
# g       NaN       NaN       NaN  NaN    NaN
# h  0.719194 -0.297595  0.874191  bar   True

# %%
pd.isna(df2["one"])
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: one, dtype: bool

# %%
df2["four"].notna()
# Out:
# a     True
# b    False
# c     True
# d    False
# e     True
# f     True
# g    False
# h     True
# Name: four, dtype: bool

# %%
df2.isna()
# Out:
#      one    two  three   four   five
# a  False  False  False  False  False
# b   True   True   True   True   True
# c  False  False  False  False  False
# d   True   True   True   True   True
# e  False  False  False  False  False
# f  False  False  False  False  False
# g   True   True   True   True   True
# h  False  False  False  False  False

# %%
df2.fillna(0)
# Out:
#         one       two     three four   five
# a -2.724919 -0.879403 -0.119714  bar  False
# b  0.000000  0.000000  0.000000    0      0
# c  0.577318 -0.241615  0.922915  bar   True
# d  0.000000  0.000000  0.000000    0      0
# e -0.415512  0.253216  0.685635  bar  False
# f  1.351467  1.846179  0.180370  bar   True
# g  0.000000  0.000000  0.000000    0      0
# h  0.719194 -0.297595  0.874191  bar   True

# %% [markdown]
# # Filling with a PandasObject

# %%
dff = pd.DataFrame(np.random.randn(10, 3), columns=list("ABC"))
dff.iloc[3:5, 0] = np.nan

dff.iloc[4:6, 1] = np.nan

dff.iloc[5:8, 2] = np.nan

dff
# Out:
#           A         B         C
# 0  0.802223  0.374259 -0.693176
# 1 -0.611092 -1.001893 -1.377472
# 2 -1.232007 -0.962625 -0.306471
# 3       NaN  0.124045  0.438191
# 4       NaN       NaN -0.054005
# 5 -0.034310       NaN       NaN
# 6 -0.784212  1.502788       NaN
# 7 -0.407088 -0.756192       NaN
# 8  1.298938  0.029861  0.997918
# 9 -1.139982 -0.357321  0.151686

# %%
dff.fillna(dff.mean())
# Out:
#           A         B         C
# 0  0.802223  0.374259 -0.693176
# 1 -0.611092 -1.001893 -1.377472
# 2 -1.232007 -0.962625 -0.306471
# 3 -0.263441  0.124045  0.438191
# 4 -0.263441 -0.130885 -0.054005
# 5 -0.034310 -0.130885 -0.120476
# 6 -0.784212  1.502788 -0.120476
# 7 -0.407088 -0.756192 -0.120476
# 8  1.298938  0.029861  0.997918
# 9 -1.139982 -0.357321  0.151686

# %%
dff.fillna(dff.mean()["B":"C"])
# Out:
#           A         B         C
# 0  0.802223  0.374259 -0.693176
# 1 -0.611092 -1.001893 -1.377472
# 2 -1.232007 -0.962625 -0.306471
# 3       NaN  0.124045  0.438191
# 4       NaN -0.130885 -0.054005
# 5 -0.034310 -0.130885 -0.120476
# 6 -0.784212  1.502788 -0.120476
# 7 -0.407088 -0.756192 -0.120476
# 8  1.298938  0.029861  0.997918
# 9 -1.139982 -0.357321  0.151686

# %%
dff.where(pd.notna(dff), dff.mean(), axis="columns")
# Out:
#           A         B         C
# 0  0.802223  0.374259 -0.693176
# 1 -0.611092 -1.001893 -1.377472
# 2 -1.232007 -0.962625 -0.306471
# 3 -0.263441  0.124045  0.438191
# 4 -0.263441 -0.130885 -0.054005
# 5 -0.034310 -0.130885 -0.120476
# 6 -0.784212  1.502788 -0.120476
# 7 -0.407088 -0.756192 -0.120476
# 8  1.298938  0.029861  0.997918
# 9 -1.139982 -0.357321  0.151686

# %% [markdown]
# # Dropping axis labels with missing data: dropna

# %% [markdown]
# pd.dropna()
# pd.fillna()
#
# We want to understand you can interpolate and the method related to it
#
# Use the function replace, with scalar or list to replace missing value
#
# Read about everything in the docs
